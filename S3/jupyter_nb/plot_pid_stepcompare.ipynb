[8.5,0.3,0.2989011,-1.255194,0.3948061],
[8.55,0.3,0.2953846,-1.175921,0.4740787],
[8.6,0.3,0.2962637,-1.281978,0.3680223],
[8.65,0.3,0.2953846,-1.262092,0.387908],
[8.7,0.3,0.2953846,-1.281044,0.3689564],
[8.75,0.3,0.2953846,-1.286939,0.3630608],
[8.8,0.3,0.2953846,-1.288483,0.3615172],
[8.85,0.3,0.2936264,-1.230785,0.4192152],
[8.9,0.3,0.2936264,-1.262974,0.3870261],
[8.95,0.3,0.2945055,-1.302016,0.3479835],
[9.0,0.3,0.2936264,-1.259632,0.3903677],
[9.05,0.3,0.2936264,-1.270924,0.3790764],
[9.1,0.3,0.2918681,-1.216314,0.4336855],
[9.15,0.3,0.2927472,-1.278268,0.3717325],
[9.2,0.3,0.2901099,-1.185569,0.4644314],
[9.25,0.3,0.290989,-1.260667,0.3893328],
[9.3,0.3,0.290989,-1.258875,0.3911253],
[9.35,0.3,0.2874725,-1.141872,0.5081278],
[9.4,0.3,0.2874725,-1.205735,0.4442648],
[9.45,0.3,0.2892308,-1.28367,0.3663303],
[9.5,0.3,0.2892308,-1.25666,0.3933396],
[9.55,0.3,0.2892308,-1.246674,0.4033264],
[9.6,0.3,0.2892308,-1.242361,0.4076388],
[9.65,0.3,0.2874725,-1.182149,0.4678509],
[9.7,0.3,0.290989,-1.32852,0.3214799],
[9.75,0.3,0.2901099,-1.243583,0.4064165],
[9.8,0.3,0.2892308,-1.211476,0.4385243],
[9.85,0.3,0.290989,-1.283582,0.3664182],
[9.9,0.3,0.2901099,-1.225894,0.4241057],
[9.95,0.3,0.2918681,-1.289555,0.3604448],
])

# %% [markdown]
# Write a function to compare responses between simulation and experimental data

# %%
def pid_compare(kp, ki, kd, datamat,scale=1):
    
    # extract vectors from datamat
    tvec = datamat[:,0]
    rvec = datamat[:,1]
    yvec = datamat[:,2]
    uvec = datamat[:,3] 
    ulimvec = datamat[:,4]
    
    s = ctl.tf('s')
    
    # 3rd-order lag plant
    P = 1/((s+1)**3)
    
    # continuous-time PID
    N = 20
    C_c = kp + ki/s + s*N*kd/(s+N)
    L_c = C_c*P
    sys_c = ctl.feedback(L_c)
    
    # simulate response
    Tv, y_c = ctl.step_response(sys_c, tvec) # , X0=0.1/scale)
    
    # plot the comparison
    fig, (ax1, ax2) = plt.subplots(2,figsize=(12,12))
    #fig.suptitle('Step responses comparison')
    ax1.set_title('Step responses comparison')
    ax1.plot(tvec, rvec,'g-.', tvec, scale*y_c, 'b-',tvec, yvec,'r-')
    #ax1.set_xlabel('time (sec)')
    ax1.set_ylabel('$y(t)$ (volts)')
    ax1.legend(['ref.cmd', 'simulated plant output','experimental plant output'])
    ax1.grid(True)
    
    ax2.plot(tvec, uvec, 'g-',tvec,ulimvec,'m-')
    ax2.set_xlabel('time (sec)')
    ax2.set_ylabel('$u(t)$ (volts)')
    ax2.grid(True)
    ax2.legend(['controller output','biased & limited controller output'])
    ax2.set_title('Controller output')
    plt.show()

# %%
# use the same parameters as in the ESP32
kp = 4.8
ki = 2.74
kd = 2.1
pid_compare(kp,ki,kd,datamat,scale=0.3)
